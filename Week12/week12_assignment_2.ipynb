# %% [markdown]
# <a href="https://colab.research.google.com/github/Veena7580/Homework/blob/main/Week12/week12_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 11 Assignment
#
#
# Please do the programming exercise and verify that your code works using the tests, then think about your final project and fill out the questions in the second part.
#
# ---
# ---

# %% [markdown]
# ### 47.1: Filtering and summarizing data
#
# For this work, you'll find a data file in `https://hds5210-data.s3.amazonaws.com/complications_all.csv`.
#
# Read in the data file and create a variable called `mo_hospitals` that contains a data frame from the `complications_all.csv` file, filtered down to only contain those hospitals from the state of Missouri (MO).
#
# Then aggregate that data by hospital into a variable named `mo_summary`.  There are some key fields that we want to summarize:
# * We want to know the earliest date that each hospital was participating in any program
# * We want to know the latest date that each hospital stopped participating in any program
# * We want to know the total number of patients in the denominators of these programs
#
# Some things to note:
# * You will need to convert the `Start Date` and `End Date` to actual datetime fields
# * You will need to clean up and convert the `Denominator` field to just be numeric - the rule that you should use it to simply remove any records where the `Denominator` is `'Not Available'`
#
#
# The final result of this step should be a new data frame called `mo_summary` that contains one row for each hospital and contains the min start date, max end date, and total denominator.  Use the names `start_date`, `end_date`, and `number` for those columns in `mo_summary`.
#
#
# You do not need to create your code in the form of a function, just make sure your variable names match what I've described above so the tests work.

# %%
import pandas as pd
# This is just to show you the name to use for the variable you need to create for this step to pass.
all_hospitals = pd.read_csv('https://hds5210-data.s3.amazonaws.com/complications_all.csv')

# %%
# Do you work here and in as many cells as you need to create a variable called `mo_summary` that matches the requirements

# Filter to only include hospitals in Missouri
mo_hospitals = all_hospitals[all_hospitals['State'] == 'MO']

# Convert Start Date and End Date to datetime
mo_hospitals['Start Date'] = pd.to_datetime(mo_hospitals['Start Date'])
mo_hospitals['End Date'] = pd.to_datetime(mo_hospitals['End Date'])

# Remove records where Denominator is 'Not Available'
mo_hospitals = mo_hospitals[mo_hospitals['Denominator'] != 'Not Available']

# Convert Denominator to numeric
mo_hospitals['Denominator'] = pd.to_numeric(mo_hospitals['Denominator'])

# Aggregate the data
mo_summary = (
    mo_hospitals.groupby('Facility Name')
    .agg(
        start_date=('Start Date', 'min'),
        end_date=('End Date', 'max'),
        number=('Denominator', 'sum')
    )
)

# Display the result
mo_summary
# Out:
# <ipython-input-7-4305d87bea22>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mo_hospitals['Start Date'] = pd.to_datetime(mo_hospitals['Start Date'])
# <ipython-input-7-4305d87bea22>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mo_hospitals['End Date'] = pd.to_datetime(mo_hospitals['End Date'])
#                                     start_date   end_date  number
# Facility Name
# BARNES JEWISH HOSPITAL              2015-04-01 2018-06-30  131313
# ...

# %%
assert(mo_summary['number'].sum() == 1766908)
assert(mo_summary['start_date'].min() == pd.Timestamp(2015,4,1))
assert(mo_summary['end_date'].max() == pd.Timestamp(2018,6,30))
assert(mo_summary.shape == (108,3))
assert(mo_summary.loc['BARNES JEWISH HOSPITAL'].number == 131313)
assert(mo_summary.loc['BOONE HOSPITAL CENTER'].number == 63099)

# %% [markdown]
# ---
#
# ### 47.2 Planning your final project
#
# You should be thinking about the things we've been learning and how you can apply them to your final project.  Use the rubric to help guid your thinking and then answer the questions below.  This is meant as a guide to help you think through what you will do.

# %% [markdown]
# #### A) Data Access
#
# Your project should include data from at least three distinct types of sources.  For example: AWS S3, Relational Databases, Internet, Web Services, local files.  List what data sources you're planning to use.

# %% [markdown]
# **Double-click to enter your answer**
#
# For my project, I plan to use data from below distinct sources:
#
# AWS S3 and Databases: I will use these to access data stored in AWS S3 buckets with Python or extract structured data from relational databases like MySQL.
#
# Kaggle: I Use Kaggle to download datasets on healthcare topics like patient outcomes and hospital performance in formats such as CSV, Excel, or JSON.
#
# Data.gov and CDC APIs: These i will use to get public health datasets from Data.gov and use CDC's APIs for updated data like disease cases and vaccination rates.
#
# These sources provide reliable and organized healthcare data for easy analysis and decision-making.

# %% [markdown]
# #### B. Data Formats
#
# Your project should include data that comes in different file formats.  For example: HL7, EDI, HTML, CSV, Excel, JSON, XML.  List what data formats you're planning to use.

# %% [markdown]
# **Double-click to enter your answer**
#
# For this project, I am planning to include data in the following formats:
#
# CSV (Comma-Separated Values): I plan to use this format because it's easy to work with and can handle simple table data in almost any system.
#
# Excel (XLSX): I use this because it's great for business data, especially when I need to include things like formulas or special formatting.
#
# JSON (JavaScript Object Notation): I use JSON because it's easy to send and receive data over the web, especially for web applications.
#
# HTML (HyperText Markup Language): I use HTML to grab structured data from web pages, as its designed to organize and display information.
#
# These all allow me to handle a wide variety of data types, from simple tables to complex web data, making it easier to process, share, and analyze information across different systems and applications.

# %% [markdown]
# #### C. Objective
#
# What purpose would your project serve in a real work setting?  Take a couple of paragraphs to write down why this is an interesting product.

# %% [markdown]
# **Double-click to enter your answer**
#
# The goal of my project is to develop a data analysis tool that can extract actionable insights from healthcare data, ultimately aiding professionals in making informed decisions. In a real-world setting, it would be used to identify key trends in patient care, resource allocation, and healthcare delivery efficiency. By analyzing large datasets from multiple sources such as electronic health records (EHRs), patient demographics, and treatment outcomes it would allow healthcare organizations to improve patient outcomes, optimize resource management, and support strategic planning.
#
# As I progress with the project, my main focus will be toward refining the analysis techniques based on the specific needs of the users and the data. This tool's potential to provide predictive insights could enhance my decision-making, streamline operations, and ultimately lead to better patient care. This adaptability and predictive capability will make my interest to leverage data for continuous improvement in the healthcare field.

# %% [markdown]
# ---
#
#
#
# ## Submit your work via GitHub as normal
